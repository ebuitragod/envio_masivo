# %%
#Escribir y llenar el documento
import pandas as pd
from __future__ import print_function
#from mailmerge import MailMerge
import mailmerge
from datetime import date

#Exportarlo a pdf
from fpdf import FPDF 
from docx2pdf import convert

#Setear la contraseña
import PyPDF2
import os
import argparse

#Enviar correos masivos

# %%
def convert_to_pdf(input_docx, out_folder):
    from subprocess import  Popen
    LIBRE_OFFICE = r"/usr/bin/soffice"

    p = Popen([LIBRE_OFFICE, '--headless', '--convert-to', 'pdf', '--outdir',
               out_folder, input_docx])
    print([LIBRE_OFFICE, '--convert-to', 'pdf', input_docx])
    p.communicate()

# %%
def write_docs(cedula, nombre_completo, nombre_output,  template, path_output_docx = '', path_output_pdf = ''):
    """
    Esta función crea un .docx, lo pasa a formato pdf y setea un password. 
    Los fields del template son {'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO', 'firma'}.
    Luego lo conviLIBRE_OFFICE = r"C:\Program Files\LibreOffice\program\soffice.exe"
    """

    document = mailmerge.MailMerge(template)
    print("Fields included in {}: {}".format(template,
                                             document.get_merge_fields()))

    document.merge(
        CEDULA = cedula,
        NOMBRE_COMPLETO = nombre_completo,
        DURACIÓN = 'Un mes',
        firma = '',
        VIGENCIA = '1 al 31 de diciembre',
    )
    #Crear documentos en word
    output_docx = path_output_docx + nombre_output + '.docx'
    
    document.write(output_docx)
    print('El documento .docx de '+ cedula + '-' + nombre_completo +'ha sido creado exitosamente.')
    
    input_docx = output_docx
    #Crear documentos en pdf
    convert_to_pdf(input_docx, path_output_pdf)


#documentation https://pbpython.com/python-word-template.html
# Define the templates - assumes they are in the same directory as the code

# %%
#Set a password
def set_password(input_file, user_pass, owner_pass):
    """
    Function creates new temporary pdf file with same content,
    assigns given password to pdf and rename it with original file.
    """
    # temporary output file with name same as input file but prepended
    # by "temp_", inside same direcory as input file.
    path, filename = os.path.split(input_file)
    output_file = os.path.join(path, "contrato_" + filename)

 

    output = PyPDF2.PdfFileWriter()

 

    input_stream = PyPDF2.PdfFileReader(open(input_file, "rb"))

 

    for i in range(0, input_stream.getNumPages()):
        output.addPage(input_stream.getPage(i))

 

    outputStream = open(output_file, "wb")

 

    # Set user and owner password to pdf file
    output.encrypt(user_pass, owner_pass, use_128bit=True)
    output.write(outputStream)
    outputStream.close()

 

    # Rename temporary output file with original filename, this
    # will automatically delete temporary file
    #os.rename(output_file, input_file)

# def main():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('-i', '--input_pdf', required=True,
#                         help='Input pdf file')
#     parser.add_argument('-p', '--user_password', required=True,
#                         help='output CSV file')
#     parser.add_argument('-o', '--owner_password', default=None,
#                         help='Owner Password')
#     args = parser.parse_args()
#     set_password(args.input_pdf, args.user_password, args.owner_password)



# if __name__ == "__main__":
#     main()

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
import os.path
from docx2pdf import convert
import PyPDF2
import os
import argparse
import pandas as pd
from __future__ import print_function
from mailmerge import MailMerge
from datetime import date

correo_envio = 'codificacionicfes@cnccol.com'
pass_correo_envio = 'Juanjo0921'

def send_email(email_recipient,
               email_subject,
               email_message,
               attachment_location = '',
               attachment_location1 = ''):

    email_sender = 'codificacionicfes@cnccol.com'

    msg = MIMEMultipart()
    msg['From'] = email_sender
    msg['To'] = email_recipient
    msg['Subject'] = email_subject

    msg.attach(MIMEText(email_message, 'plain'))

    if attachment_location != '':
        filename = os.path.basename(attachment_location)
        attachment = open(attachment_location, "rb")
        part = MIMEBase('application', 'octet-stream')
        part.set_payload(attachment.read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                        "attachment; filename= %s" % filename)
        msg.attach(part)

        filename1 = os.path.basename(attachment_location1)
        attachment1 = open(attachment_location1, "rb")
        part = MIMEBase('application', 'octet-stream')
        part.set_payload(attachment1.read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                        "attachment; filename= %s" % filename1)
        msg.attach(part)

    try:
        server = smtplib.SMTP('smtp.office365.com', 587)
        server.ehlo()
        server.starttls()
        server.login('codificacionicfes@cnccol.com', 'Vum14113')
        text = msg.as_string()
        server.sendmail(email_sender, email_recipient, text)
        print('el correo ha sido enviado a: ' + email_recipient)
        server.quit()
    except:
        print("SMPT server connection error")
    return True

# %%
from time import sleep
#import numpy as np
#base['correo_enviado'] = np.nan

# %%
#Convertir Monitores.xlsx en diccionario
#===paths
path = '01_codificadores/'
path_contratos = path + '01_contratos/'
path_acuerdos = path + '02_acuerdos_confidencialidad'
#===base
base_codificadores = pd.read_excel(path  + '01_Codificadores contratar.xlsx')
base = base_codificadores

#===documentos
acuerdo = path + '01_ACUERDO DE CONFIDENCIALIDAD VF.docx'
contrato = path + '01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx'

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Nombre                             342 non-null    object
#  1   Cédula                             342 non-null    int64
#  2   Total                              341 non-null    float64
#  3   Rol                                342 non-null    object
#  4   Correo electrónico                 342 non-null    object
#  5   Celular                            335 non-null    object
#  6   Observación                        6 non-null      object
#  7   Confirmación                       342 non-null    int64
#  8   Dirección Residencia               342 non-null    object
#  9   Municipio o ciudad de residencia   341 non-null    object
#  10  Número de Teléfono                 341 non-null    object
#  11  Horario de preferencia:            342 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 32.2+ KB

# %%
base = base[['Nombre', 'Cédula', 'Correo electrónico']]

# %%
base['correo_enviado'] = base['Cédula']
base['Cédula'] = base['Cédula'].astype(str)
base['Correo electrónico'].astype(str)
# Out:
# <ipython-input-36-90e7cf702c68>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['correo_enviado'] = base['Cédula']
# <ipython-input-36-90e7cf702c68>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Cédula'] = base['Cédula'].astype(str)
# 0           florez.diana682@gmail.com
# 1            sandramile07@hotmail.com
# 2      carolitacortesforero@gmail.com
# 3            arturo.ortiz67@gmail.com
# 4              santi.dz4530@gmail.com
#                     ...
# 337     yeraldin.corredor@hotmail.com
# 338        cristobalcajigas@gmail.com
# 339             licmarlon01@gmail.com
# 340               nquirogad@gmail.com
# 341              dianamrs09@gmail.com
# Name: Correo electrónico, Length: 342, dtype: object

# %%
base['correo_enviado']
# Out:
# 0      1020739682
# 1        52152715
# 2        39546490
# 3      1107051161
# 4      1019125821
#           ...
# 337    1030578326
# 338    1085245324
# 339    1022348004
# 340    1020820014
# 341    1022950252
# Name: correo_enviado, Length: 342, dtype: int64

# %%
#Documentos y valores de las funciones
contrato = '01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx'
acuerdo = '01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx'

# %%
#para el envio del correo
content = open('email_codificadores.txt')
email_subject = 'recursoshumanos1@cnccol.com'
email_message = content.read()

# %%
from validate_email import validate_email 
list = []

for index, row in base.iterrows():
    correo = row['Correo electrónico']
    is_valid = validate_email(correo)
    if is_valid == False:
        list.append(correo)
    else:
        sleep(5)
        nombre_completo = row['Nombre']
        #print(nombre_completo)
        cedula = row['Cédula']
        #print(cedula)
        nombre_output = cedula + ' - ' + nombre_completo + ': Contrato como codificador. CNC'
        #Escribiendo contratos
        template = contrato
        path_output_docx = '01_codificadores/01_contratos/'
        path_output_pdf = '01_codificadores/03_attachments/'
        write_docs(cedula, nombre_completo, nombre_output,  template, path_output_docx, path_output_pdf)
        input_file = path_output_pdf + nombre_output + '.pdf'
        #user_pass = cedula
        #owner_pass = 'ContratosCodific4d0r3sCNC!'
        #sleep(3)
        #set_password(input_file, user_pass, owner_pass)

        #Escribiendo acuerdos
        sleep(5)
        template = acuerdo
        nombre_output = cedula + ' - ' + nombre_completo + ': Acuerdo de confidencialidad. CNC'
        path_output_docx = '01_codificadores/02_acuerdos_confidencialidad/'
        path_output_pdf = '01_codificadores/03_attachments/'
        write_docs(cedula, nombre_completo, nombre_output,  template, path_output_docx, path_output_pdf)
        input_file1 = path_output_pdf + nombre_output + '.pdf'
        #user_pass = cedula
        #owner_pass = 'ContratosCodific4d0r3sCNC!'
        #sleep(3)
        #set_password(input_file, user_pass, owner_pass)
        
        sleep(10)
        email_recipient = row['Correo electrónico']
        attachment_location = input_file
        attachment_location1 = input_file1

        row['correo_enviado'] = send_email(email_recipient, email_subject, email_message, attachment_location, attachment_location1)
# Out:
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 1020739682-Diana Marcela Nuñez Florezha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/1020739682 - Diana Marcela Nuñez Florez: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 1020739682-Diana Marcela Nuñez Florezha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/02_acuerdos_confidencialidad/1020739682 - Diana Marcela Nuñez Florez: Acuerdo de confidencialidad. CNC.docx']
# el correo ha sido enviado a: florez.diana682@gmail.com
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 52152715-Sandra Milena Cruz Hernandezha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/52152715 - Sandra Milena Cruz Hernandez: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 52152715-Sandra Milena Cruz Hernandezha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/02_acuerdos_confidencialidad/52152715 - Sandra Milena Cruz Hernandez: Acuerdo de confidencialidad. CNC.docx']
# el correo ha sido enviado a: sandramile07@hotmail.com
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 39546490-Carolina Cortes Foreroha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/39546490 - Carolina Cortes Forero: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 39546490-Carolina Cortes Foreroha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/02_acuerdos_confidencialidad/39546490 - Carolina Cortes Forero: Acuerdo de confidencialidad. CNC.docx']
# el correo ha sido enviado a: carolitacortesforero@gmail.com
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 1107051161-Helbert Helbert Ortizha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/1107051161 - Helbert Helbert Ortiz: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 1107051161-Helbert Helbert Ortizha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/02_acuerdos_confidencialidad/1107051161 - Helbert Helbert Ortiz: Acuerdo de confidencialidad. CNC.docx']
# el correo ha sido enviado a: arturo.ortiz67@gmail.com
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 1019125821-Santiago Diaz Camachoha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/1019125821 - Santiago Diaz Camacho: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 1019125821-Santiago Diaz Camachoha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/02_acuerdos_confidencialidad/1019125821 - Santiago Diaz Camacho: Acuerdo de confidencialidad. CNC.docx']
# el correo ha sido enviado a: santi.dz4530@gmail.com
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 1013596167-Fabio Enrique Ramirez Espitiaha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/1013596167 - Fabio Enrique Ramirez Espitia: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 1013596167-Fabio Enrique Ramirez Espitiaha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/02_acuerdos_confidencialidad/1013596167 - Fabio Enrique Ramirez Espitia: Acuerdo de confidencialidad. CNC.docx']
# el correo ha sido enviado a: comoledije92@gmail.com
# Fields included in 01_codificadores/01_CC6193-01 Minuta codificador(a) Icfes VF 231120.docx: {'VIGENCIA', 'firma', 'CEDULA', 'DURACIÓN', 'NOMBRE_COMPLETO'}
# El documento .docx de 1015414029-Angelica Paola Balda Jimenezha sido creado exitosamente.
# ['/usr/bin/soffice', '--convert-to', 'pdf', '01_codificadores/01_contratos/1015414029 - Angelica Paola Balda Jimenez: Contrato como codificador. CNC.docx']
# Fields included in 01_codificadores/01_ACUERDO DE CONFIDENCIALIDAD VF.docx: {'NOMBRE_COMPLETO', 'CEDULA'}
# El documento .docx de 